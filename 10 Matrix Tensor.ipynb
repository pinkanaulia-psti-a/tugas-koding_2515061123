# %%
#1

# %%
import numpy as np

# %%
# Use array() with nested brackets:
X = np.array([[25, 150], [61,1], [2, 3]])
X
# Out:
# array([[ 25, 150],
#        [ 61,   1],
#        [  2,   3]])

# %%
X.size
# Out:
# 6

# %%
X[:,0]
# Out:
# array([25, 61,  2])

# %%
X[1,:]
# Out:
# array([61,  1])

# %%
#2

# %%
import torch

# %%
X_pt = torch.tensor([[25, 150], [61, 1], [2, 3]])
X_pt
# Out:
# tensor([[ 25, 150],
#         [ 61,   1],
#         [  2,   3]])

# %%
X_pt.shape
# Out:
# torch.Size([3, 2])

# %%
X_pt[1,:]
# Out:
# tensor([61,  1])

# %%
import tensorflow as tf

# %%
X_tf = tf.Variable([[25, 150], [61, 1], [2, 3]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3, 2) dtype=int32, numpy=
# array([[ 25, 150],
#        [ 61,   1],
#        [  2,   3]], dtype=int32)>

# %%
tf.shape(X_tf)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([3, 2], dtype=int32)>

# %%
X_tf[1,:]
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([61,  1], dtype=int32)>
