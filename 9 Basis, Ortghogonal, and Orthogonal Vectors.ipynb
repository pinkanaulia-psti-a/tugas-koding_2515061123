# %%
#1

# %%
import numpy as np

# %%
i = np.array([1, 0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0, 1])
j
# Out:
# array([0, 1])

# %%
np.dot(i, j)
# Out:
# np.int64(0)

# %%
#2

# %%
v = np.array([1, 2])
v
# Out:
# array([1, 2])

# %%
w = np.array([2, -1])
w
# Out:
# array([ 2, -1])

# %%
np.dot(v, w)
# Out:
# np.int64(0)
