# %%
#scalar

# %%
#1

# %%
#buat variabel skalar x dan simpan suatu nilai skalar
x = 1123
print(x)
# Out:
# 1123

# %%
#tampilkan tipe data dari x
print("Nilai x:", x)
print("Tipe data x:", type (x))
# Out:
# Nilai x: 1123
# Tipe data x: <class 'int'>

# %%
#buat variabel skalar y dan simpan suatu nilai skalar
y = 1123
print(y)
# Out:
# 1123

# %%
#tampilkan tipe data dari y
print("Nilai x:", y)
print("Tipe data y:", y)
# Out:
# Nilai x: 1123
# Tipe data y: 1123

# %%
#jumlahkan x + y
hasil_xy = x + y
print("Hasil x = y:", hasil_xy)
# Out:
# Hasil x = y: 2246

# %%
#Buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 1123.0

# %%
x = 1123
py_sum = x + y
py_sum
# Out:
# 2246

# %%
#Tampilkan Tipe data dari x_float
print("Tipe data x_float:", type(x_float))
# Out:
# Tipe data x_float: <class 'float'>

# %%
#2

# %%
import torch

# %%
x_pt = torch.tensor(1123) # type specification optional, e.g.: dtype=torch.float16
x_pt
# Out:
# tensor(1123)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %%
#3
import tensorflow as tf

# %%
x_tf = tf.Variable(1123.0, dtype=tf.float32)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=1123.0>

# %%
y_tf2 = tf.Variable(0.1123)

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(1123, dtype=tf.int16)

# %%
x_tf + tf.cast(y_tf, dtype=tf.float32)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2246.0>

# %%
tf_sum = tf.add(x_tf, tf.cast(y_tf, dtype=tf.float32))
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=2246.0>

# %%
tf_sum.numpy() # note that NumPy operations automatically convert tensors to NumPy arrays, and vice versa
# Out:
# np.float32(2246.0)

# %%
type(tf_sum.numpy())
# Out:
# numpy.float32

# %%
tf_float = tf.Variable(1123., dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=1123.0>
