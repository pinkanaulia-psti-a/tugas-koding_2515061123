# %%
import numpy as np

# %%
v = np.array([[25],
              [2],
              [-3],
              [-23]])

print("Vektor Asli:")
print(v)
print("Bentuk:", v.shape)
# Out:
# Vektor Asli:
# [[ 25]
#  [  2]
#  [ -3]
#  [-23]]
# Bentuk: (4, 1)

# %%
v_transpose = v.T
print("\nHasil Transpose:")
print(v_transpose)
print("Bentuk:", v_transpose.shape)
# Out:
# Hasil Transpose:
# [[ 25   2  -3 -23]]
# Bentuk: (1, 4)
