# %% [markdown]
# ### Vectors (Rank 1 Tensors) in NumPy

# %%
#Vector

# %%
#1
import numpy as np

# %%
x = np.array([11, 2, 3]) # type argument is optional, e.g.: dtype=np.float16
x
# Out:
# array([11,  2,  3])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0] # zero-indexed
# Out:
# np.int64(11)

# %%
type(x[0])
# Out:
# numpy.int64

# %%
#2

# %%
x_t = x.T
x_t
# Out:
# array([11,  2,  3])

# %%
x_t.shape
# Out:
# (3,)

# %%
y = np.array([[11, 2, 3]])
y
# Out:
# array([[11,  2,  3]])

# %%
y.shape
# Out:
# (1, 3)

# %%
#3

# %%
import torch
import tensorflow as tf

# %%
x_pt = torch.tensor([11, 2, 3])
x_pt
# Out:
# tensor([11,  2,  3])

# %%
x_tf = tf.Variable([11, 2, 3])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([11,  2,  3], dtype=int32)>
